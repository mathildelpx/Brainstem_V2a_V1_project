# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import sys
sys.path.insert(1, '../utils/')
from clustering_analysis import *
sys.path.insert(1, '../tools/')
from list_tools import *

# %%
# %matplotlib inline

sns.set()
sns.set_style("dark")

# %% [markdown]
# ## Checking clustering algorithm
#
# Here this a mega cluster with  **2 fish with OMR**.
#
# I tried different number of clusters.

# %% [markdown]
# ### N= 3 CLUSTERS

# %%
path = '/home/mathilde.lapoix/Bureau/ZZBehaviorAnalysis/results/'
clusterName = 'OMRDataTest3clusters'
fishOfInterest = '200813_F1'

with open(path+clusterName+'/output_dataframe_short', 'rb') as f:
    df = pickle.load(f)

df_long = pd.read_csv(path+clusterName+'/output_dataframe.csv')

# Load the tail angle for all these bouts
nbFramesTakenIntoAccount = 65

df = new_df_cluster(df_long, nbFramesTakenIntoAccount, fishOfInterest)
fig_clustering(df, '200813_F1')
fig_params(df, path, clusterName)

plot_violin_kinematics_class(df, 2, 3, path, clusterName)
kinematics_hist_global(df, path, clusterName)

# %%
density_plot_per_cat(df)
kdensity_plot_per_cat(df)

# %% [markdown]
# ### N=4 CLUSTERS

# %%
path = '/home/mathilde.lapoix/Bureau/ZZBehaviorAnalysis/results/'
clusterName = 'OMRDataTest4clusters'
fishOfInterest = '200813_F1'

with open(path+clusterName+'/output_dataframe_short', 'rb') as f:
    df = pickle.load(f)

df_long = pd.read_csv(path+clusterName+'/output_dataframe.csv')

# Load the tail angle for all these bouts
nbFramesTakenIntoAccount = 65

df = new_df_cluster(df_long, nbFramesTakenIntoAccount, fishOfInterest)
fig_clustering(df, '200813_F1')
fig_params(df, path, clusterName)

plot_violin_kinematics_class(df, 2, 3, path, clusterName)
kinematics_hist_global(df, path, clusterName)

# %%
density_plot_per_cat(df)
kdensity_plot_per_cat(df)

# %% [markdown]
# ### N=5 CLUSTERS

# %%
path = '/home/mathilde.lapoix/Bureau/ZZBehaviorAnalysis/results/'
clusterName = 'OMRDataTest5clusters'
fishOfInterest = '200813_F1'

with open(path+clusterName+'/output_dataframe_short', 'rb') as f:
    df = pickle.load(f)

df_long = pd.read_csv(path+clusterName+'/output_dataframe.csv')

# Load the tail angle for all these bouts
nbFramesTakenIntoAccount = 65

df = new_df_cluster(df_long, nbFramesTakenIntoAccount, fishOfInterest)
fig_clustering(df, '200813_F1')
fig_params(df, path, clusterName)

plot_violin_kinematics_class(df, 2, 3, path, clusterName)
kinematics_hist_global(df, path, clusterName)
